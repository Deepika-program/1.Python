# %%
#print statement

print("HOPE AI")
# Out:
# HOPE AI

# %%
#Buy Input
print(input("Enter your Institute Name ? :"))
# Out:
# Enter your Institute Name ? : HOPE AI
# HOPE AI

# %%
#Buy Inputs
input("Enter your Name :")
input("Enter your Age :")
input("Enter your School Name :")
input("Enter your Degree :")
# Out:
# Enter your Name : Deepika T
# Enter your Age : 33
# Enter your School Name : SVS school
# Enter your Degree : B.E (ECE)
# 'B.E (ECE)'

# %%
#Addition
a=43
b=34
print("a = ",a)
print("b = ",b)
print("Add = ",a+b)
# Out:
# a =  43
# b =  34
# Add =  77

# %%
#subtraction
a=43
b=34
print("a = ",a)
print("b = ",b)
print("Sub = ",a-b)
# Out:
# a =  43
# b =  34
# Sub =  9

# %%
#Multiplication
a=63
b=97
print("a = ",a)
print("b = ",b)
print("Mul = ",a*b)
# Out:
# a =  63
# b =  97
# Mul =  6111

# %%
#True Division
a=76
b=31
print("a = ",a)
print("b = ",b)
print("Div = ",a/b)
# Out:
# a =  76
# b =  31
# Div =  2.4516129032258065

# %%
#Floor Division
a=76
b=31
print("a = ",a)
print("b = ",b)
print("Div = ",a//b)
# Out:
# a =  76
# b =  31
# Div =  2

# %%
#Modulo
a=76
b=31
print("a = ",a)
print("b = ",b)
print("Modulo = ",a%b)
# Out:
# a =  76
# b =  31
# Modulo =  14

# %%
#Power
a=4
b=4
print("a = ",a)
print("b = ",b)
print("Power = ",a**b)
# Out:
# a =  4
# b =  4
# Power =  256
