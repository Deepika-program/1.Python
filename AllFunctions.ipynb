# %%
from pythonBasicFunctions import multiplefunctions

# %%
multiplefunctions.OddEven()
# Out:
# Enter the number 78653
# Odd Number
# 'Odd Number'

# %%
multiplefunctions.CheckEligibility()
# Out:
# Your Gender: Female
# Your Age: 12
# NOT ELIGIBLE
# 'NOT ELIGIBLE'
