# %%
from pythonAssignmentlibrary import AssignmentFinalFunc

# %%
AssignmentFinalFunc.OddEven()
# Out:
# Enter the number 7851
# 7851 is Odd Number
# 'Odd Number'

# %%
AssignmentFinalFunc.CheckEligibility()
# Out:
# Your Gender: Male
# Your Age: 26
# ELIGIBLE
# 'ELIGIBLE'

# %%
AssignmentFinalFunc.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing
# 'Natural Language Processing'

# %%
AssignmentFinalFunc.Area_triangle()
# Out:
# Height :  32
# Breadth :  34
# Area of Triangle:  544.0

# %%
AssignmentFinalFunc.Perimeter_triangle(2,2,4)
# Out:
# Height1: 2
# Height2: 2
# Breadth: 4
# Perimeter of Triangle :  8

# %%
AssignmentFinalFunc.FindResult()
# Out:
# Subject1 :  92
# Subject2 :  89
# Subject3 :  94
# Subject4 :  94
# Subject5 :  81
# Total : 450
# percentage : 90.0
