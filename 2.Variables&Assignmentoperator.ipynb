# %%
num1=10
num2=20
add=num1+num2
print("add")
# Out:
# add

# %%
num1=10
num2=20
add=num1+num2
print("add")
print(add)
# Out:
# add
# 30

# %%
First name ="Deepika Purushothaman"
# Out:
#   Cell In[3], line 1
#     First name ="Deepika Purushothaman"
#           ^
# SyntaxError: invalid syntax

# %%
First_name ="Deepika Purushothaman"
print(First_name)
# Out:
# Deepika Purushothaman

# %%
FirstName = "Deepika T"
print(FirstName)
# Out:
# Deepika T

# %%
firstName = "Hello"
print(firstName)
# Out:
# Hello

# %%
@First = "hi"
print(@First)
# Out:
#   Cell In[8], line 1
#     @First = "hi"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
1Firstname = "Welcome"
print(1Firstname)
# Out:
#   Cell In[9], line 1
#     1Firstname = "Welcome"
#     ^
# SyntaxError: invalid decimal literal

# %%
F1 = "check"
print(F1)
# Out:
# check

# %%
num1=10
num2=30
add=num1+num2
print("The addition of two numbers")
print("num1 :",num1)
print("num2 :",num2)
print("Add :",add)
# Out:
# The addition of two numbers
# num1 : 10
# num2 : 30
# Add : 40

# %%
num1=input("Enter the num1 :")
# Out:
# Enter the num1 : 2

# %%
num2=input("Enter the num2 :")
# Out:
# Enter the num2 : 4

# %%
add=num1+num2
print(add)
# Out:
# 24

# %%
num1=int(input("Enter the num1 :"))
# Out:
# Enter the num1 : 2

# %%
num2=int(input("Enter the num2 :"))
# Out:
# Enter the num2 : 4

# %%
add=num1+num2
print(add)
# Out:
# 6
